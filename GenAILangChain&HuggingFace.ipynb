# %% [markdown]
# Generative AI Course with LangChain & Hugging Face
# 1. Python Programming Language: Numpy,Pandas,File Operations
# 2. NLP in Deep Learning: RNN, LSTM, RNN, GRU RNN, Bidirectional RNN, Encoder, Decoder, Attention Mechanism, Transformer, Bert => Basic building block => LLM Models & GenAI
# 3. LangChain Ecosystem: GenAI Framework, For building GenAI Apps,LLM, Multi Model, Open Source LLM,Agents, Chat with SQL DB, Vector DB, Retirivers, Text Summarizatoin, Cahtbot with chat message history.
#  1. LangChain
#  2. LangChain Core
#  3. LangChain Community
#  4. LangChain Tools
#
# 4. Deployment Techniques: Free Resourses WRT deployment, Streamlit Framework,
#
# 5. Fine Tuning Techniques: Google Collab, OpenAI, Quantization, Lora => Fine Tune with Open Source LLM Models
#
# 6. Gen AI in AWS : AWS BedRock, Lamda Function, API Gateway, AWS Sagemaker
#
# 7. Nvidia NIM: Deploy Gen AI Models in cloud by using LangChain
#
# 8. CREW AI: Multi AI Agents => Different Gen AI Apps
#
# 9. LLM and Multi Model: OpenAI GPT 4.0, GPT 4 Turbo OPEN AI Embedding
#
# 10. Google => Gemma, Gemma 2
#
# 11. Meta => Llama 3, Code Lamma
#
# 12. Anthropic => Mistral
#
# 13. Hugging Face => Models
#
# 14. GROK AI Infrastructure => LPU Engine and how it is better than GPUs
